-- %%
CREATE OR REPLACE TABLE formula1_incr.gold.ref_driver_code (
    driver_id       STRING,
    fia_driver_code STRING
)
USING DELTA;

INSERT OVERWRITE formula1_incr.gold.ref_driver_code
SELECT *
FROM VALUES
    ('hamilton', 'HAM'),
    ('max_verstappen', 'VER'),
    ('leclerc', 'LEC'),
    ('russell', 'RUS'),
    ('sainz', 'SAI'),
    ('norris', 'NOR'),
    ('piastri', 'PIA'),
    ('alonso', 'ALO'),
    ('stroll', 'STR'),
    ('gasly', 'GAS'),
    ('ocon', 'OCO'),
    ('tsunoda', 'TSU'),
    ('hulkenberg', 'HUL'),
    ('bottas', 'BOT'),
    ('zhou', 'ZHO'),
    ('albon', 'ALB'),
    ('sargeant', 'SAR'),
    ('ricciardo', 'RIC'),
    ('bearman', 'BEA'),
    ('antonelli', 'ANT'),
    ('colapinto', 'COL'),
    ('lawson', 'LAW'),
    ('hadjar', 'HAD'),
    ('bortoleto', 'BOR'),
    ('doohan', 'DOO'),
    ('kvyat', 'KVY'),
    ('kubica', 'KUB'),
    ('giovinazzi', 'GIO'),
    ('latifi', 'LAT'),
    ('mazepin', 'MAZ'),
    ('de_vries', 'DEV'),
    ('mick_schumacher', 'MSC'),
    ('kevin_magnussen', 'MAG'),
    ('perez', 'PER'),
    ('gutierrez', 'GUT'),
    ('wehrlein', 'WEH'),
    ('vandoorne', 'VAN'),
    ('massa', 'MAS'),
    ('vettel', 'VET'),
    ('webber', 'WEB'),
    ('button', 'BUT'),
    ('rosberg', 'ROS'),
    ('raikkonen', 'RAI'),
    ('grosjean', 'GRO'),
    ('kobayashi', 'KOB'),
    ('sutil', 'SUT'),
    ('buemi', 'BUE'),
    ('vergne', 'VGN'),
    ('nasr', 'NAS'),
    ('maldonado', 'MAL'),
    ('heidfeld', 'HEI'),
    ('wurz', 'WUR'),
    ('gene', 'GEN'),
    ('panis', 'PAN'),
    ('liuzzi', 'LIU'),
    ('klien', 'KLI'),
    ('badoer', 'BAD'),
    ('fisichella', 'FIS'),
    ('piquet_jr', 'PIQ'),
    ('karthikeyan', 'KAR'),
    ('chandhok', 'CHA'),
    ('brendon_hartley', 'HAR'),
    ('sirotkin', 'SIR'),
    ('ericsson', 'ERI'),
    ('palmer', 'PAL'),
    ('haryanto', 'NTO'),
    ('merhi', 'MER'),
    ('rossi', 'OSI'),
    ('stevens', 'STE'),
    ('pic', 'PIC'),
    ('chilton', 'CHI'),
    ('bianchi', 'BIA'),
    ('van_der_garde', 'VDG'),
    ('senna', 'SEN'),
    ('petrov', 'PET'),
    ('dambrosio', 'DAM'),
    ('trulli', 'TRU'),
    ('glock', 'GLO'),
    ('kovalainen', 'KOV'),
    ('di_grassi', 'DIG'),
    ('yamamoto', 'YAM'),
    ('aitken', 'AIT'),
    ('pietro_fittipaldi', 'FIT')
AS ref_driver_code(driver_id, fia_driver_code);
