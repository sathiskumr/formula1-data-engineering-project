-- %%
CREATE SCHEMA IF NOT EXISTS formula1ext.control
    MANAGED LOCATION 'abfss://formula1@formula1extdl.dfs.core.windows.net/control';

-- %%
CREATE TABLE IF NOT EXISTS formula1ext.control.batch_events
(
    batch_id INT,
    event_timestamp TIMESTAMP
)

-- %%
INSERT INTO formula1ext.control.batch_events
VALUES (1, current_timestamp());

-- %%
INSERT INTO formula1ext.control.batch_events
VALUES (2, current_timestamp());

-- %%
SELECT * FROM formula1ext.control.batch_events;
