# %%
# %fs ls 'abfss://formula1-incremental@formula1extdl.dfs.core.windows.net/'

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `formula1_ext_dl_formula1-incremental`
URL 'abfss://formula1-incremental@formula1extdl.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `formula1-sc`)
COMMENT 'External location for the formula1-incremental container';

# %%
# %fs ls 'abfss://formula1-incremental@formula1extdl.dfs.core.windows.net/landing'

# %%
# %sql
SHOW CATALOGS;

# %%
# %sql
DROP CATALOG IF EXISTS formula1ext CASCADE;

# %%
# %sql
CREATE CATALOG IF NOT EXISTS formula1_incr
  MANAGED LOCATION 'abfss://formula1-incremental@formula1extdl.dfs.core.windows.net/'
  COMMENT "This is main catalog for the formula1-incremental project";

# %%
# %sql

CREATE SCHEMA IF NOT EXISTS formula1_incr.landing;
CREATE SCHEMA IF NOT EXISTS formula1_incr.bronze
  MANAGED LOCATION 'abfss://formula1-incremental@formula1extdl.dfs.core.windows.net/bronze';

CREATE SCHEMA IF NOT EXISTS formula1_incr.silver
  MANAGED LOCATION 'abfss://formula1-incremental@formula1extdl.dfs.core.windows.net/silver';

CREATE SCHEMA IF NOT EXISTS formula1_incr.gold
  MANAGED LOCATION 'abfss://formula1-incremental@formula1extdl.dfs.core.windows.net/gold';

# %%
# %sql

SHOW SCHEMAS

# %%
# %sql
USE CATALOG formula1_incr;
SHOW SCHEMAS;

# %%
# %sql
CREATE EXTERNAL VOLUME formula1_incr.landing.files
LOCATION 'abfss://formula1-incremental@formula1extdl.dfs.core.windows.net/landing';

# %%
# %fs ls /Volumes/formula1_incr/landing/files
